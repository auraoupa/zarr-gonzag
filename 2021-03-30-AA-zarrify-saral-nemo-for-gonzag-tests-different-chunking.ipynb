# %%
import xarray as xr
import zarr
import numcodecs

# %%
ds_alt1=xr.open_dataset('/Users/auraoupa/Work/git/gonzag/dt_global_alg_sla_vxxc_20170402_SARAL-Altika.nc',chunks={'time':100})

# %%
ds_alt1
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 44533)
# Coordinates:
#   * time            (time) datetime64[ns] 2017-04-01T23:57:40.480926208 ... 2...
#     longitude       (time) float64 dask.array<chunksize=(100,), meta=np.ndarray>
#     latitude        (time) float64 dask.array<chunksize=(100,), meta=np.ndarray>
# Data variables:
#     cycle           (time) int16 dask.array<chunksize=(100,), meta=np.ndarray>
#     track           (time) int16 dask.array<chunksize=(100,), meta=np.ndarray>
#     adt_unfiltered  (time) float64 dask.array<chunksize=(100,), meta=np.ndarray>
#     sla_unfiltered  (time) float64 dask.array<chunksize=(100,), meta=np.ndarray>
# Attributes: (12/45)
#     history:                         Sun Jan 14 12:30:34 2018: ncwa -O -a rec...
#     NCO:                             20180114
#     nco_openmp_thread_number:        1
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
# ...

# %%
compressor = numcodecs.Blosc(cname='snappy', clevel=6, shuffle=-1)
encoding = {vname: {'compressor': compressor} for vname in ds_alt1.variables}
outdir = '/Users/auraoupa/Work/git/gonzag/zarr_dt_global_alg_sla_vxxc_20170402_SARAL-Altika_chunksby100'
ds_alt1.to_zarr(outdir, encoding=encoding, mode="w")

# %%
ds_alt2=xr.open_dataset('/Users/auraoupa/Work/git/gonzag/dt_global_alg_sla_vxxc_JFM_2017_SARAL-Altika.nc',chunks={'time':100})
compressor = numcodecs.Blosc(cname='snappy', clevel=6, shuffle=-1)
encoding = {vname: {'compressor': compressor} for vname in ds_alt2.variables}
outdir = '/Users/auraoupa/Work/git/gonzag/zarr_dt_global_alg_sla_vxxc_JFM_2017_SARAL-Altika_chunksby100'
ds_alt2.to_zarr(outdir, encoding=encoding, mode="w")

# %%
ds_nemo1=xr.open_dataset('/Users/auraoupa/Work/git/gonzag/ssh_ORCA1_20170101_20171231_grid_T.nc',chunks={'y':100,'x':100})
compressor = numcodecs.Blosc(cname='snappy', clevel=6, shuffle=-1)
encoding = {vname: {'compressor': compressor} for vname in ds_nemo1.variables}
outdir = '/Users/auraoupa/Work/git/gonzag/zarr_ssh_ORCA1_20170101_20171231_grid_T_chunksby100'
ds_nemo1.to_zarr(outdir, encoding=encoding, mode="w")

# %%
ds_nemo2=xr.open_dataset('/Users/auraoupa/Work/git/gonzag/sossheig_box_Faroe_eNATL60-BLBT02_20170101-20170331.nc',chunks={'x':100,'y':100})
compressor = numcodecs.Blosc(cname='snappy', clevel=6, shuffle=-1)
encoding = {vname: {'compressor': compressor} for vname in ds_nemo2.variables}
outdir = '/Users/auraoupa/Work/git/gonzag/zarr_sossheig_box_Faroe_eNATL60-BLBT02_20170101-20170331_chunksby100'
ds_nemo2.to_zarr(outdir, encoding=encoding, mode="w")
